# %%
import pandas as pd

# %%
df=pd.read_csv("/content/BlackFriday (1).csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.drop("Product_Category_2",axis=1,inplace=True)
df.drop("Product_Category_3",axis=1,inplace=True)
'''using del key word
del df["Product_Category_2"]
del df["Product_Category_3"]'''
# Out:
# 'using del key word\ndel df["Product_Category_2"]\ndel df["Product_Category_3"]'

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
#maretial status
#0-singlr
#1-married
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
print(df['Stay_In_Current_City_Years'].nunique())
print(df['Age'].nunique())
print(df['City_Category'].nunique)
# Out:
# 5
# 7
# <bound method IndexOpsMixin.nunique of 0         A
# 1         A
# 2         A
# 3         A
# 4         C
#          ..
# 537572    C
# 537573    C
# 537574    C
# 537575    C
# 537576    C
# Name: City_Category, Length: 537577, dtype: object>

# %%
print(df['Age'].nunique())
# Out:
# 7

# %%
print(df['Stay_In_Current_City_Years'].unique())
# Out:
# ['2' '4+' '3' '1' '0']

# %%
#df['Marital_Status'].str.replace("0","single") data is present in the int form so here we want to add the string
#so we need to convert the data type into the string using the astype()
df['Marital_Status']=df['Marital_Status'].astype("str")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  object
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 41.0+ MB

# %%
df['Marital_Status']=df['Marital_Status'].str.replace("0","single").str.replace("1","married")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  Purchase
# 0                          2         single                   3      8370
# 1                          2         single                   1     15200
# 2                          2         single                  12      1422
# 3                          2         single                  12      1057
# 4                         4+         single                   8      7969

# %%
#a-kolkata
#b=delhi
#c-mumbai
df['City_Category']=df['City_Category'].str.replace("")

# %%
#how can we use the loop in  the collumn
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
for i in df.columns:
  print(i,":",df[i].nunique(),df[i].unique())
# Out:
# User_ID : 5891 [1000001 1000002 1000003 ... 1004113 1005391 1001529]
# Product_ID : 3623 ['P00069042' 'P00248942' 'P00087842' ... 'P00038842' 'P00295642'
#  'P00091742']
# Gender : 2 ['F' 'M']
# Age : 7 ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']
# Occupation : 21 [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# City_Category : 3 ['A' 'C' 'B']
# Stay_In_Current_City_Years : 5 ['2' '4+' '3' '1' '0']
# Marital_Status : 2 ['single' 'married']
# Product_Category_1 : 18 [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9]
# Purchase : 17959 [ 8370 15200  1422 ... 14539 11120 18426]

# %%
df.describe()
# Out:
#             User_ID    Occupation  Product_Category_1       Purchase
# count  5.375770e+05  537577.00000       537577.000000  537577.000000
# mean   1.002992e+06       8.08271            5.295546    9333.859853
# std    1.714393e+03       6.52412            3.750701    4981.022133
# min    1.000001e+06       0.00000            1.000000     185.000000
# 25%    1.001495e+06       2.00000            1.000000    5866.000000
# 50%    1.003031e+06       7.00000            5.000000    8062.000000
# 75%    1.004417e+06      14.00000            8.000000   12073.000000
# max    1.006040e+06      20.00000           18.000000   23961.000000

# %%
df["Product_ID"].describe()
# Out:
# count        537577
# unique         3623
# top       P00265242
# freq           1858
# Name: Product_ID, dtype: object

# %%
df['City_Category'].describe()
# Out:
# count     537577
# unique         3
# top            B
# freq      226493
# Name: City_Category, dtype: object

# %%
from __future__ import print_function # how can we uuse loop for knwoing the all discription of the colun in one click
for i in df.columns:
  print(i,":",df[i].describe())
  print("--"*40)
# Out:
# User_ID : count    5.375770e+05
# mean     1.002992e+06
# std      1.714393e+03
# min      1.000001e+06
# 25%      1.001495e+06
# 50%      1.003031e+06
# 75%      1.004417e+06
# max      1.006040e+06
# Name: User_ID, dtype: float64
# --------------------------------------------------------------------------------
# Product_ID : count        537577
# unique         3623
# top       P00265242
# freq           1858
# Name: Product_ID, dtype: object
# --------------------------------------------------------------------------------
# Gender : count     537577
# unique         2
# top            M
# freq      405380
# Name: Gender, dtype: object
# --------------------------------------------------------------------------------
# Age : count     537577
# unique         7
# top        26-35
# freq      214690
# Name: Age, dtype: object
# --------------------------------------------------------------------------------
# Occupation : count    537577.00000
# mean          8.08271
# ...

# %%
df['Gender'].describe()
# Out:
# count     537577
# unique         2
# top            M
# freq      405380
# Name: Gender, dtype: object

# %%
df['Gender']=="M"
df['Gender']=="F"
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 537572    False
# 537573    False
# 537574    False
# 537575    False
# 537576    False
# Name: Gender, Length: 537577, dtype: bool

# %%
#if we want to know the length of the male and female then we can use the len function
len(df[df['Gender']=="M"])
# Out:
# 405380

# %%
len(df[df['Gender']=="F"])
# Out:
# 132197

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    405380
# F    132197
# Name: count, dtype: int64

# %%
df.groupby("Gender").count()
# Out:
#         User_ID  Product_ID     Age  Occupation  City_Category  \
# Gender
# F        132197      132197  132197      132197         132197
# M        405380      405380  405380      405380         405380
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# Gender
# F                           132197          132197              132197
# M                           405380          405380              405380
#
#         Purchase
# Gender
# F         132197
# M         405380

# %%
df.groupby("Gender").size().plot(kind="pie",autopct="%.2f",title="Gender Ratio")
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby("Gender").size().plot(kind="bar")# if we want to know the number of m and f then we can use then this bar and % we can use the pie chart
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby("Gender").sum()["Purchase"]
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby("Age").size().plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df.groupby("Age").sum()["Product_ID"]
# Out:
# Age
# 0-17     P00069042P00248942P00087842P00085442P00112542P...
# 18-25    P00366542P00190742P00151842P00112642P00118442P...
# 26-35    P00193542P00274942P00251242P00014542P00031342P...
# 36-45    P00036842P00085942P00118742P00297942P00266842P...
# 46-50    P00184942P00346142P0097242P00129542P00140742P0...
# 51-55    P00231342P00190242P0096642P00058442P00019342P0...
# 55+      P00285442P00117442P00322042P00216342P00329342P...
# Name: Product_ID, dtype: object

# %%
df.groupby("Age")["Product_ID"].nunique()
# Out:
# Age
# 0-17     2300
# 18-25    3213
# 26-35    3419
# 36-45    3318
# 46-50    3099
# 51-55    2877
# 55+      2573
# Name: Product_ID, dtype: int64

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
len(df[df['Age']=='0-17'])
# Out:
# 14707

# %%
#if we want the store the value the n we need to use the df[df["Age"]==i] like this []
for i in df["Age"].unique():
  print(i,":",len(df[df["Age"]==i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %%
lst=[]
for i in df["Age"].unique():
  print(i,":",df[df["Age"]==i]["Product_ID"].nunique())
  lst.append(df[df["Age"]==i]["Product_ID"].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
df.groupby("Age").sum()["Purchase"]
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df.groupby("Age").sum()["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").sum()["Purchase"].plot(kind="pie",autopct="%.2f")
#autopct="%.2f this portion is responsible for the calculating in the percentage .
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Age").mean(numeric_only=True)["Purchase"]
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby("Age").mean(numeric_only=True)["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
import seaborn as sns

# %%
df.groupby("Age").size().plot(kind="pie",autopct="%.2f",title="Age Ratio")
#
# Out:
# <Axes: title={'center': 'Age Ratio'}>

# %%
df.groupby("Age").size().plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.countplot(x="Age",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Gender",data=df,hue="Marital_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind="pie",autopct="%.2f",title="City Ratio")
# Out:
# <Axes: title={'center': 'City Ratio'}>

# %%
df.groupby("City_Category").size().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
sns.countplot(x="City_Category",data=df,hue="Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"]
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby("City_Category").mean(numeric_only=True)["Purchase"]
# Out:
# City_Category
# A    8958.011014
# B    9198.657848
# C    9844.441855
# Name: Purchase, dtype: float64

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="pie",autopct="%.2f",title="City Ratio")
# Out:
# <Axes: title={'center': 'City Ratio'}, ylabel='Purchase'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
df.groupby("City_Category").mean(numeric_only=True)["Purchase"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/List of Countries by Sugarcane Production.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                   Country      Continent Production (Tons)  \
# 0           0                    Brazil  South America       768.678.382
# 1           1                     India           Asia       348.448.000
# 2           2                     China           Asia       123.059.739
# 3           3                  Thailand           Asia        87.468.496
# 4           4                  Pakistan           Asia        65.450.704
# 5           5                    Mexico  North America        56.446.821
# 6           6                  Colombia  South America        36.951.213
# 7           7                 Australia        Oceania        34.403.004
# 8           8                 Guatemala  North America        33.533.403
# 9           9  United States of America  North America        29.926.210
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df.shape
# Out:
# (103, 7)

# %%
df.nunique()
# Out:
# Unnamed: 0                    103
# Country                       103
# Continent                       6
# Production (Tons)             103
# Production per Person (Kg)    102
# Acreage (Hectare)             102
# Yield (Kg / Hectare)          102
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df["Production (Tons)"].str.replace(".","")
# Out:
# 0      768678382
# 1      348448000
# 2      123059739
# 3       87468496
# 4       65450704
#          ...
# 98            97
# 99            53
# 100           50
# 101           12
# 102            1
# Name: Production (Tons), Length: 103, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.rename(columns={'Production (Tons)':'Production_(Tons)','Production per Person (Kg)':'Production_per_Person_(Kg)','Acreage (Hectare)':'Acreage_(Hectare)','Yield (Kg / Hectare)':'Yield_(Kg/Hectare)'}, inplace=True)
df['Production_per_Person_(Kg)']=df['Production_per_Person_(Kg)'].astype(str).str.replace('.', '', regex=False).str.replace(',', '.', regex=False)
df['Acreage_(Hectare)']=df['Acreage_(Hectare)'].astype(str).str.replace('.', '', regex=False)
df['Production_(Tons)']=df['Production_(Tons)'].astype(str).str.replace('.', '', regex=False)
df['Yield_(Kg/Hectare)']=df['Yield_(Kg/Hectare)'].astype(str).str.replace('.', '', regex=False).str.replace(',', '.', regex=False)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3668531          10226205               751675
# 1                     260721           4950000               703935
# 2                      88287           1675215               734591
# 3                    1264303           1336575               654422
# 4                     324219           1130820                57879

# %%
df.rename(columns={'Production (Tons)':'Production_(Tons)','Production per Person (Kg)':'Production_per_Person_(Kg)','Acreage (Hectare)':'Acreage_(Hectare)','Yield (Kg / Hectare)':'Yield_(Kg/Hectare)'}, inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production_(Tons) Production_per_Person_(Kg)  \
# 0    Brazil  South America        7686783820                   36685310
# 1     India           Asia        3484480000                    2607210
# 2     China           Asia        1230597390                     882870
# 3  Thailand           Asia         874684960                   12643030
# 4  Pakistan           Asia         654507040                    3242190
#
#   Acreage_(Hectare) Yield_(Kg/Hectare)
# 0         102262050            7516750
# 1          49500000            7039350
# 2          16752150            7345910
# 3          13365750            6544220
# 4          11308200             578790

# %%
df['Production_(Tons)']=df['Production_(Tons)'].astype(float)
df['Production_per_Person_(Kg)']=df['Production_per_Person_(Kg)'].astype(float)
df['Acreage_(Hectare)']=df['Acreage_(Hectare)'].astype(float)
df['Yield_(Kg/Hectare)']=df['Yield_(Kg/Hectare)'].astype(float)

# %%
df.head()
# Out:
#     Country      Continent  Production_(Tons)  Production_per_Person_(Kg)  \
# 0    Brazil  South America       7.686784e+09                  36685310.0
# 1     India           Asia       3.484480e+09                   2607210.0
# 2     China           Asia       1.230597e+09                    882870.0
# 3  Thailand           Asia       8.746850e+08                  12643030.0
# 4  Pakistan           Asia       6.545070e+08                   3242190.0
#
#    Acreage_(Hectare)  Yield_(Kg/Hectare)
# 0        102262050.0           7516750.0
# 1         49500000.0           7039350.0
# 2         16752150.0           7345910.0
# 3         13365750.0           6544220.0
# 4         11308200.0            578790.0

# %%
df.dtypes
# Out:
# Country                        object
# Continent                      object
# Production_(Tons)             float64
# Production_per_Person_(Kg)    float64
# Acreage_(Hectare)             float64
# Yield_(Kg/Hectare)            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                       0
# Continent                     0
# Production_(Tons)             0
# Production_per_Person_(Kg)    0
# Acreage_(Hectare)             0
# Yield_(Kg/Hectare)            0
# dtype: int64

# %%
df[df['Acreage_(Hectare)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, Continent, Production_(Tons), Production_per_Person_(Kg), Acreage_(Hectare), Yield_(Kg/Hectare)]
# Index: []

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# Country                       0
# Continent                     0
# Production_(Tons)             0
# Production_per_Person_(Kg)    0
# Acreage_(Hectare)             0
# Yield_(Kg/Hectare)            0
# dtype: int64

# %% [markdown]
# Analysis

# %% [markdown]
# how many country produce sugarcane form each country?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind="bar")
plt.xlabel("Continent")
# Out:
# Text(0.5, 0, 'Continent')

# %%
df.describe()
# Out:
#        Production_(Tons)  Production_per_Person_(Kg)  Acreage_(Hectare)  \
# count       1.020000e+02                1.020000e+02       1.020000e+02
# mean        1.850372e+08                4.124805e+06       2.498981e+06
# std         8.419149e+08                8.669140e+06       1.137003e+07
# min         1.000000e+01                0.000000e+00       0.000000e+00
# 25%         6.251875e+05                1.075225e+05       1.104000e+04
# 50%         1.440044e+07                8.135850e+05       1.655800e+05
# 75%         6.426824e+07                2.828128e+06       8.047400e+05
# max         7.686784e+09                4.816299e+07       1.022620e+08
#
#        Yield_(Kg/Hectare)
# count        1.020000e+02
# mean         5.018502e+06
# std          3.169530e+06
# min          1.000000e+02
# 25%          2.487505e+06
# 50%          5.102500e+06
# 75%          7.198920e+06
# max          1.290493e+07

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.boxenplot(df['Production_(Tons)'])
plt.title("Production_(Tons)")
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person_(Kg)'])
plt.title("Production_per_Person_(Kg)")
plt.subplot(2,2,3)
sns.boxplot(df['Acreage_(Hectare)'])
plt.title("Acreage_(Hectare)")
plt.subplot(2,2,4)
sns.boxplot(df['Yield_(Kg/Hectare)'])
plt.title("Yield_(Kg/Hectare)")
# Out:
# Text(0.5, 1.0, 'Yield_(Kg/Hectare)')

# %%
sns.violinplot(x="Continent",y="Production_(Tons)",data=df)
# Out:
# <Axes: xlabel='Continent', ylabel='Production_(Tons)'>

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.histplot(df['Production_(Tons)'],bins=10)
plt.title("Production_(Tons)")
plt.subplot(2,2,2)
sns.histplot(df['Production_per_Person_(Kg)'],bins=10)
plt.title("Production_per_Person_(Kg)")
plt.subplot(2,2,3)
sns.histplot(df['Acreage_(Hectare)'],bins=10)
plt.title("Acreage_(Hectare)")
plt.subplot(2,2,4)
sns.histplot(df['Yield_(Kg/Hectare)'],bins=10)
plt.title("Yield_(Kg/Hectare)")
# Out:
# Text(0.5, 1.0, 'Yield_(Kg/Hectare)')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.distplot(df['Production_(Tons)'])
plt.title("Production_(Tons)")
plt.subplot(2,2,2)
sns.distplot(df['Production_per_Person_(Kg)'])
plt.title("Production_per_Person_(Kg)")
plt.subplot(2,2,3)
sns.distplot(df['Acreage_(Hectare)'])
plt.title("Acreage_(Hectare)")
plt.subplot(2,2,4)
sns.distplot(df['Yield_(Kg/Hectare)'])
plt.title("Yield_(Kg/Hectare)")
# Out:
# /tmp/ipython-input-803583105.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production_(Tons)'])
# /tmp/ipython-input-803583105.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production_per_Person_(Kg)'])
# ...

# %%
sns.violinplot(df["Production_(Tons)"])
# Out:
# <Axes: ylabel='Production_(Tons)'>

# %%
df
# Out:
#        Country      Continent  Production_(Tons)  Production_per_Person_(Kg)  \
# 0       Brazil  South America       7.686784e+09                  36685310.0
# 1        India           Asia       3.484480e+09                   2607210.0
# 2        China           Asia       1.230597e+09                    882870.0
# 3     Thailand           Asia       8.746850e+08                  12643030.0
# 4     Pakistan           Asia       6.545070e+08                   3242190.0
# ..         ...            ...                ...                         ...
# 97       Spain         Europe       3.940000e+03                        80.0
# 98     Lebanon           Asia       9.700000e+02                       160.0
# 99   Singapore           Asia       5.000000e+02                        90.0
# 100      Samoa        Oceania       1.200000e+02                        60.0
# 101      Syria           Asia       1.000000e+01                         0.0
#
#      Acreage_(Hectare)  Yield_(Kg/Hectare)
# ...

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %% [markdown]
# ### which country produce maximum sugarcane continent wise?.

# %%
df_africa=df[df['Continent']=='Africa']
df_africa.sort_values(by='Production_(Tons)',ascending=False)
# Out:
#                      Country Continent  Production_(Tons)  \
# 15                     Egypt    Africa        157604180.0
# 16              South Africa    Africa        150746100.0
# 22                     Kenya    Africa         70946190.0
# 26                 Swaziland    Africa         55832950.0
# 27                     Sudan    Africa         55250590.0
# 31                    Zambia    Africa         42858390.0
# 34                 Mauritius    Africa         37984480.0
# 35                    Uganda    Africa         37230190.0
# 36                  Zimbabwe    Africa         34830000.0
# 38                Madagascar    Africa         30056410.0
# 39                  Tanzania    Africa         29941270.0
# 40                    Malawi    Africa         29154060.0
# 41                Mozambique    Africa         27615050.0
# 44            Congo-Kinshasa    Africa         21913330.0
# 46             Côte d'Ivoire    Africa         19826610.0
# ...

# %%
df_asia=df[df['Continent']=='Asia']
df_asia.sort_values(by='Production_(Tons)',ascending=False)
# Out:
#          Country Continent  Production_(Tons)  Production_per_Person_(Kg)  \
# 1          India      Asia       3.484480e+09                   2607210.0
# 2          China      Asia       1.230597e+09                    882870.0
# 3       Thailand      Asia       8.746850e+08                  12643030.0
# 4       Pakistan      Asia       6.545070e+08                   3242190.0
# 10     Indonesia      Asia       2.715883e+08                    102480.0
# 11   Philippines      Asia       2.237055e+08                   2102320.0
# 14       Vietnam      Asia       1.631314e+08                   1723340.0
# 17       Myanmar      Asia       1.043706e+08                   1937710.0
# 20          Iran      Asia       7.687593e+07                     94030.0
# 30         Nepal      Asia       4.346754e+07                   1487650.0
# 32    Bangladesh      Asia       4.207592e+07                    254810.0
# 45          Laos      Asia       2.019000e+07                   2900360.0
# ...

# %%
maximum_production=df_africa.sort_values(by='Production_(Tons)',ascending=False)
a=maximum_production['Production_(Tons)'].head(1).tolist()
max_prod=a[0]
print(max_prod)
# Out:
# 157604180.0

# %%
df['prod_per%']=(df['Production_(Tons)']/df['Production_(Tons)'].sum())*100
df.head()
# Out:
#     Country      Continent  Production_(Tons)  Production_per_Person_(Kg)  \
# 0    Brazil  South America       7.686784e+09                  36685310.0
# 1     India           Asia       3.484480e+09                   2607210.0
# 2     China           Asia       1.230597e+09                    882870.0
# 3  Thailand           Asia       8.746850e+08                  12643030.0
# 4  Pakistan           Asia       6.545070e+08                   3242190.0
#
#    Acreage_(Hectare)  Yield_(Kg/Hectare)  prod_per%
# 0        102262050.0           7516750.0  40.727285
# 1         49500000.0           7039350.0  18.462001
# 2         16752150.0           7345910.0   6.520138
# 3         13365750.0           6544220.0   4.634389
# 4         11308200.0            578790.0   3.467809

# %%
df['prod_per%']=(df['Production_(Tons)']/df['Production_(Tons)'].sum())*100
df.head()
new_df=df[['Country','prod_per%']]
new_df['prod_per%'].plot(kind='pie',autopct='%.2f')
new_df.head()
# Out:
#     Country  prod_per%
# 0    Brazil  40.727285
# 1     India  18.462001
# 2     China   6.520138
# 3  Thailand   4.634389
# 4  Pakistan   3.467809

# %%
df['prod_per%']=(df['Production_(Tons)']/df['Production_(Tons)'].sum())*100
df.head()
new_df=df[['Country','prod_per%']]
new_df['prod_per%'].head(10).plot(kind='pie',autopct='%.2f')
new_df.head()
# Out:
#     Country  prod_per%
# 0    Brazil  40.727285
# 1     India  18.462001
# 2     China   6.520138
# 3  Thailand   4.634389
# 4  Pakistan   3.467809

# %% [markdown]
#  ### which country has highest production?

# %%
sorted_production_tons=df[['Country','Production_(Tons)']].sort_values(by='Production_(Tons)',ascending=False)
sorted_production_tons['per%']=(sorted_production_tons['Production_(Tons)']/sorted_production_tons['Production_(Tons)'].sum())*100
sorted_production_tons.head(10)
top_5=sorted_production_tons.iloc[0:5:]
other_countries=sorted_production_tons.iloc[5::]
other_per=other_countries['per%'].sum()
top_6=top_5._append({'Country':'Other','Production_(Tons)':other_countries['Production_(Tons)'].sum(),'per%':other_per},ignore_index=True)
top_6
plt.pie(top_6['per%'],labels=top_6['Country'],autopct='%1.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7d2d95040d40>,
# ...
#  [Text(0.3159289157346693, 1.0536550290311892, 'Brazil'),
#   Text(-1.099996221450406, 0.0028831917781463796, 'India'),
#   Text(-0.7802885355560173, -0.7753385075435413, 'China'),
#   Text(-0.46669230860335165, -0.9960915063840642, 'Thailand'),
#   Text(-0.20084060739323964, -1.0815096164260005, 'Pakistan'),
#   Text(0.7482434544804235, -0.8063074679222577, 'Other')],
#  [Text(0.17232486312800144, 0.5747209249261032, '40.7'),
#   Text(-0.5999979389729487, 0.0015726500608071162, '18.5'),
#   Text(-0.42561192848510027, -0.4229119132055679, '6.5'),
#   Text(-0.25455944105637357, -0.5433226398458532, '4.6'),
#   Text(-0.10954942221449433, -0.5899143362323639, '3.5'),
#   Text(0.4081327933529582, -0.4398040734121405, '26.2')])

# %% [markdown]
# ### correlation

# %%
df
# Out:
#        Country      Continent  Production_(Tons)  Production_per_Person_(Kg)  \
# 0       Brazil  South America       7.686784e+09                  36685310.0
# 1        India           Asia       3.484480e+09                   2607210.0
# 2        China           Asia       1.230597e+09                    882870.0
# 3     Thailand           Asia       8.746850e+08                  12643030.0
# 4     Pakistan           Asia       6.545070e+08                   3242190.0
# ..         ...            ...                ...                         ...
# 97       Spain         Europe       3.940000e+03                        80.0
# 98     Lebanon           Asia       9.700000e+02                       160.0
# 99   Singapore           Asia       5.000000e+02                        90.0
# 100      Samoa        Oceania       1.200000e+02                        60.0
# 101      Syria           Asia       1.000000e+01                         0.0
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                             Production_(Tons)  Production_per_Person_(Kg)  \
# Production_(Tons)                    1.000000                    0.352369
# Production_per_Person_(Kg)           0.352369                    1.000000
# Acreage_(Hectare)                    0.997550                    0.341974
# Yield_(Kg/Hectare)                   0.121125                    0.226719
# prod_per%                            1.000000                    0.352369
#
#                             Acreage_(Hectare)  Yield_(Kg/Hectare)  prod_per%
# Production_(Tons)                    0.997550            0.121125   1.000000
# Production_per_Person_(Kg)           0.341974            0.226719   0.352369
# Acreage_(Hectare)                    1.000000            0.107826   0.997550
# Yield_(Kg/Hectare)                   0.107826            1.000000   0.121125
# prod_per%                            0.997550            0.121125   1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# do countries with highest land produce more sugarcane

# %%
#scatter plot
plt.scatter(df['Acreage_(Hectare)'],df['Production_(Tons)'])
plt.xlabel('Acreage_(Hectare)')
plt.ylabel('Production_(Tons)')
plt.title('Acreage vs Production')
# Out:
# Text(0.5, 1.0, 'Acreage vs Production')

# %%
#scatterplot
plt.scatter(x=df['Yield_(Kg/Hectare)'],y=df['Production_(Tons)'])
plt.xlabel('Yield_(Kg/Hectare)')
plt.ylabel('Production_(Tons)')
plt.title('Yield vs Production')
# Out:
# Text(0.5, 1.0, 'Yield vs Production')

# %%
sns.scatterplot(data=df,x='Yield_(Kg/Hectare)',y='Production_(Tons)',hue='Continent')
# Out:
# <Axes: xlabel='Yield_(Kg/Hectare)', ylabel='Production_(Tons)'>

# %% [markdown]
# analysis for CONTINENT

# %%
df_continent = df.groupby('Continent').sum()
df_continent.head()
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
#
#                Production_(Tons)  Production_per_Person_(Kg)  \
# Continent
# Africa              8.968147e+08                 101441100.0
# Asia                7.219304e+09                  31208080.0
# Europe              5.823000e+04                      5360.0
# North America       1.739959e+09                 154209530.0
# Oceania             3.617757e+08                  31580660.0
#
#                Acreage_(Hectare)  Yield_(Kg/Hectare)  prod_per%
# Continent
# Africa                14390890.0         207004540.0   4.751640
# ...

# %%
df_continent = df.groupby('Continent').value_counts()
df_continent.head(100)
# Out:
# Continent      Country       Production_(Tons)  Production_per_Person_(Kg)  Acreage_(Hectare)  Yield_(Kg/Hectare)  prod_per%
# Africa         Angola        5560940.0          190120.0                    142550.0           3901160.0           0.029464     1
#                Benin         120170.0           10580.0                     5980.0             2009530.0           0.000637     1
#                Burkina Faso  4848720.0          239510.0                    48230.0            10052630.0          0.025690     1
#                Burundi       2181150.0          20420.0                     29980.0            7275350.0           0.011557     1
#                Cameroon      12887320.0         541620.0                    1359840.0          947710.0            0.068282     1
#                                                                                                                                ..
# ...

# %%
df_continent = df.groupby('Continent').sum(numeric_only=True)
df_continent['number_of_countries']=df.groupby('Continent').count()['Country']
df_continent.head()
# Out:
#                Production_(Tons)  Production_per_Person_(Kg)  \
# Continent
# Africa              8.968147e+08                 101441100.0
# Asia                7.219304e+09                  31208080.0
# Europe              5.823000e+04                      5360.0
# North America       1.739959e+09                 154209530.0
# Oceania             3.617757e+08                  31580660.0
#
#                Acreage_(Hectare)  Yield_(Kg/Hectare)  prod_per%  \
# Continent
# Africa                14390890.0         207004540.0   4.751640
# Asia                 106083190.0         111973080.0  38.250414
# Europe                     710.0          13187090.0   0.000309
# North America         15819830.0          95811620.0   9.218918
# Oceania                4909090.0          16241910.0   1.916815
#
#                number_of_countries
# Continent
# Africa                          38
# Asia                            25
# Europe                           2
# ...

# %% [markdown]
# which continent produces maximum sugarcane ?

# %%
df_continent = df_continent.sort_values(ascending=False)
df_continent.plot(kind='bar')
plt.xlabel('Continent')
plt.ylabel('Production_(Tons)')
plt.title('Production_(Tons)')
# Out:
# Text(0.5, 1.0, 'Production_(Tons)')

# %%
df_continent = df.groupby('Continent').sum(numeric_only=True)
df_continent['number_of_countries']=df.groupby('Continent').count()['Country']
df_continent['number_of_countries'].sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Continent')
plt.ylabel('Number of Countries')
plt.title('Number of Countries per Continent')
# Out:
# Text(0.5, 1.0, 'Number of Countries per Continent')

# %%
sns.lineplot(data=df_continent,x='Acreage_(Hectare)',y='Production_(Tons)')
plt.xlabel('Acreage_(Hectare)')
plt.ylabel('Production_(Tons)')
plt.title('Acreage vs Production')
# Out:
# Text(0.5, 1.0, 'Acreage vs Production')

# %%
df_continent['Production_(Tons)'].plot(kind='pie',autopct='%1.1f')
plt.title('Percentage of Sugarcane Production by Continent')
# Out:
# Text(0.5, 1.0, 'Percentage of Sugarcane Production by Continent')
